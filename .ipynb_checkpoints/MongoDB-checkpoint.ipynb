# %%
import pprint
import re
import pymongo, json

pp = pprint.PrettyPrinter(indent=1,width=65)

client = pymongo.MongoClient (host="da1.eecs.utk.edu")
db = client ['fdac19mp2']
coll = db ['ddasilva']
# for each dataset
coll.insert_one ( { 'topic':'Hurricane Data', 'title': 'Hurricanes and Typhoons, 1851-2014', 'license': 'CCO:Public Domain', 'description': 'Location, wind, and pressure of tropical cyclones in Atlantic and Pacific Oceans', 'urls': [ 'https://www.kaggle.com/noaa/hurricane-database'] } )
coll.insert_one ( { 'topic':'Hurricane Data', 'title': 'Hurricane wind speeds.', 'license': 'NA', 'description': 'The mean sustained hurricane wind speed in knots (kt) as taken from NOAA [25], mean distances in kilometre (km) from selected tracking-points to CNP and the modelled mean, minimum and maximum wind speeds at CNP are listed.', 'urls': [ 'https://plos.figshare.com/articles/_Hurricane_wind_speeds_/957193' ] } )
coll.insert_one ( { 'topic':'Hurricane Data', 'title': 'Hurricane Harvey Tweets', 'license': 'CC0:Public Domain', 'description': 'Recent tweets on Hurricane Harvey', 'urls': [ 'https://www.kaggle.com/dan195/hurricaneharvey' ] } )
coll.insert_one ( { 'topic':'Hurricane Data', 'title': 'WMO Hurricane Survival Dataset', 'license': 'CC0:Public Domain', 'description': 'Can you predict who will survive the Hurricane?', 'urls': [ 'https://www.kaggle.com/rahulsathyajit/wmo-hurricane-survival-dataset'] } )
coll.insert_one ( { 'topic':'Hurricane Data', 'title': 'Mussel Watch', 'license': 'CC0:Public Domain', 'description': 'The longest running contaminant monitoring program in U.S. coastal waters', 'urls': [ 'https://www.kaggle.com/sohier/mussel-watch'] } )
coll.insert_one ( { 'topic':'Hurricane Data', 'title': 'Hurricane News Headlines 2017', 'license': 'CC0:Public Domain', 'description': 'Use for linguistic analysis or make time-series graphs of hurricane season 2017.', 'urls': [ 'https://www.kaggle.com/anm431/hurricane-news-headlines-2017'] } )
coll.insert_one ( { 'topic':'Hurricane Data', 'title': 'City of Houston Hurricane Harvey Damage Assessment', 'license': 'CC0: Public Domain', 'description': 'NA', 'urls': [ 'https://www.kaggle.com/evgeniya1/city-of-houston-hurricane-harvey-damage-assessment'] } )
coll.insert_one ( { 'topic':'Disaster Data', 'title': 'Federal Emergencies and Disasters, 1953-Present', 'license': 'CC0:Public Domain', 'description': 'Has the number of emergencies declared by the president risen over time?', 'urls': [ 'https://www.kaggle.com/fema/federal-disasters'] } )
coll.insert_one ( { 'topic':'Hurricane Data', 'title': 'Category_4', 'license': 'Public Domain', 'description': 'Category 4 level hurricane dataset', 'urls': [ 'https://www.kaggle.com/vedantc6/category-4'] } )
coll.insert_one ( { 'topic':'Disaster Data', 'title': 'Natural Disaster Data', 'license': 'Public Domain', 'description': 'Occurrence and economic impact', 'urls': [ 'https://www.kaggle.com/dataenergy/natural-disaster-data'] } )
coll.insert_one ( { 'topic':'Disaster Data', 'title': 'Disasters on social media', 'license': 'Public Domain', 'description': 'Which tweets are relevant news and which are just banter?', 'urls': [ 'https://www.kaggle.com/jannesklaas/disasters-on-social-media'] } )
coll.insert_one ( { 'topic':'Disaster Human Data', 'title': 'Human Mobility During Natural Disasters', 'license': 'Public Domain', 'description': 'Twitter geolocation for users during 15 natural disasters', 'urls': [ 'https://www.kaggle.com/dryad/human-mobility-during-natural-disasters'] } )
coll.insert_one ( { 'topic':'Earthquake Data', 'title': 'Significant Earthquakes, 1965-2016', 'license': 'Public Domain', 'description': 'Date, time, and location of all earthquakes with magnitude of 5.5 or higher', 'urls': [ 'https://www.kaggle.com/usgs/earthquake-database']  } )
coll.insert_one ( { 'topic':'Earthquake Data', 'title': 'Sample Earthquake Data', 'license': 'Public Domain', 'description': 'NA', 'urls': [ 'https://www.kaggle.com/nksingh673/sample-earthquake-data'] } )
coll.insert_one ( { 'topic':'Tsunami Data', 'title': 'Tsunami Causes and Waves', 'license': 'Public Domain', 'description': 'Cause, magnitude, and intensity of every tsunami since 2000 BC', 'urls': [ 'https://www.kaggle.com/noaa/seismic-waves' ] } )
coll.insert_one ( { 'topic':'Earthquake Data', 'title': 'Stanford Earthquake Dataset', 'license': 'World Bank', 'description': 'NA', 'urls': [ 'https://www.kaggle.com/mostafamousavi/stanford-earthquake-dataset'] } )
coll.insert_one ( { 'topic':'Earthquake Data', 'title': 'Seismic Center - earthquake FB-prediction post', 'license': 'Public Domain', 'description': 'csv containing the comments under the viral post from @cutremur.vrancea', 'urls': [ 'https://www.kaggle.com/saileeen/seismic-center-rom-earthquake-prediction-post' ] } )
coll.insert_one ( { 'topic':'Hurricane Data', 'title': 'Hurricane wind speeds.', 'license': 'NA', 'description': 'The mean sustained hurricane wind speed in knots (kt) as taken from NOAA [25], mean distances in kilometre (km) from selected tracking-points to CNP and the modelled mean, minimum and maximum wind speeds at CNP are listed.', 'urls': [ 'https://plos.figshare.com/articles/_Hurricane_wind_speeds_/957193' ] } )
coll.insert_one ( { 'topic':'Hurricane Data', 'title': 'Hurricane Harvey Tweets', 'license': 'CC0:Public Domain', 'description': 'Recent tweets on Hurricane Harvey', 'urls': [ 'https://www.kaggle.com/dan195/hurricaneharvey' ] } )
coll.insert_one ( { 'topic':'Disaster Data', 'title': 'Federal Emergencies and Disasters, 1953-Present', 'license': 'CC0:Public Domain', 'description': 'Has the number of emergencies declared by the president risen over time?', 'urls': [ 'https://www.kaggle.com/fema/federal-disasters'] } )

# %%
import pprint
import pymongo, json
client = pymongo.MongoClient (host="da1.eecs.utk.edu")
db = client ['fdac19mp2']
coll = db ['ddasilva']
pp = pprint.PrettyPrinter(indent=1,width=65)
for r in coll. find():
  print(pp .pformat (r))
# Out:
# {'_id': ObjectId('5d88d94fb22652b8d049a6a7'),
#  'description': 'Location, wind, and pressure of tropical '
#                 'cyclones in Atlantic and Pacific Oceans',
#  'license': 'CCO:Public Domain',
#  'title': 'Hurricanes and Typhoons, 1851-2014',
#  'topic': 'Hurricane Data',
#  'urls': ['https://www.kaggle.com/noaa/hurricane-database']}
# {'_id': ObjectId('5d88d94fb22652b8d049a6a8'),
#  'description': 'Location, wind, and pressure of tropical '
#                 'cyclones in Atlantic and Pacific Oceans',
#  'license': 'CCO:Public Domain',
#  'title': 'Hurricanes and Typhoons, 1851-2014',
#  'topic': 'Hurricane Data',
#  'urls': ['https://www.kaggle.com/noaa/hurricane-database']}
# {'_id': ObjectId('5d88d966b22652b8d049a6ab'),
#  'description': 'Location, wind, and pressure of tropical '
#                 'cyclones in Atlantic and Pacific Oceans',
#  'license': 'CCO:Public Domain',
#  'title': 'Hurricanes and Typhoons, 1851-2014',
#  'topic': 'Hurricane Data',
# ...
